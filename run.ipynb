# %%
# %cd /content
from google.colab import drive
drive.mount('/content/drive')
# %rm /content/drive/MyDrive/run.sh
# !git clone https://github.com/yangcurve/free-sdw
# %cp free-sdw/run.sh /content
# %rm -rf free-sdw
# !sh /content/run.sh
